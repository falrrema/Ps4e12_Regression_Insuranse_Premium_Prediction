# %% [markdown]
# # **Autogluon 4hr log tpu**

# %%
# %%capture
# %pip install setuptools wheel autogluon.tabular[all,skex] dask[dataframe]
# %pip install -U -q ipywidgets
# %pip install -U scikit-learn

# %%
# Import basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
import cloudpickle
import plotly.io as pio
import plotly.graph_objects as go
from autogluon.core.metrics import make_scorer
import sklearn
from plotly.subplots import make_subplots
pd.options.plotting.backend = "plotly"
pio.templates.default = "simple_white"
warnings.filterwarnings('ignore')

# Import specific libraries
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#base_path = os.getenv('DATA_FOLDER_PATH', 'Data/')
base_path = os.getenv('DATA_FOLDER_PATH', '/content/drive/MyDrive/DS_Projects/Playground_Series/Ps4e12_Regression_Insuranse_Premium_Prediction/Data/')

train = pd.read_csv(os.path.join(base_path, 'train.csv'))
test = pd.read_csv(os.path.join(base_path, 'test.csv'))
submission = pd.read_csv(os.path.join(base_path, 'sample_submission.csv'))
original = pd.read_csv(os.path.join(base_path, 'Insurance Premium Prediction Dataset.csv'))

# %%
train.set_index('id', inplace=True)
test.set_index('id', inplace=True)

# Renaming columns for consistency
train.columns = train.columns.str.lower()
test.columns = test.columns.str.lower()
original.columns = original.columns.str.lower()
train.columns = [col.replace(" ", "_") for col in train.columns]
test.columns = [col.replace(" ", "_") for col in test.columns]
original.columns = [col.replace(" ", "_") for col in original.columns]
original  = original[train.columns]
original = original.dropna(subset=['premium_amount'])

# %% [markdown]
# # **Feature Engineering**

# %%
def create_date_features(df):
    # Basic date features
    df['policy_start'] = pd.to_datetime(df['policy_start_date'])
    df['year'] = df['policy_start'].dt.year
    df['month'] = df['policy_start'].dt.month
    df['day'] = df['policy_start'].dt.day
    df['week_of_year'] = df['policy_start'].dt.isocalendar().week.astype('int')
    df['day_of_week'] = df['policy_start'].dt.day_name()
    df['month_name'] = df['policy_start'].dt.month_name()
    df['quarter'] = df['policy_start'].dt.quarter

    # Cyclical encoding
    for col, max_val in [('year', 1), ('month', 12), ('day', 31)]:
        df[f'{col}_sin'] = np.sin(2 * np.pi * df[col] / max_val)
        df[f'{col}_cos'] = np.cos(2 * np.pi * df[col] / max_val)

    # Binary flags
    df['is_weekend'] = df['policy_start'].dt.dayofweek.isin([5,6]).astype(int)
    df['is_month_end'] = df['policy_start'].dt.is_month_end.astype(int)
    df['is_month_start'] = df['policy_start'].dt.is_month_start.astype(int)
    df['is_quarter_end'] = df['policy_start'].dt.is_quarter_end.astype(int)
    df['is_quarter_start'] = df['policy_start'].dt.is_quarter_start.astype(int)

    # Time-based calculations
    df['policy_age_days'] = (df['policy_start'].max() - df['policy_start']).dt.days
    df['week_of_month'] = df['day'].apply(lambda x: (x-1)//7 + 1)
    df['days_in_month'] = df['policy_start'].dt.days_in_month
    df['days_remaining_in_month'] = df['days_in_month'] - df['day']

    # Seasonal mapping
    season_map = {12:'winter', 1:'winter', 2:'winter',
                  3:'spring', 4:'spring', 5:'spring',
                  6:'summer', 7:'summer', 8:'summer',
                  9:'fall', 10:'fall', 11:'fall'}
    df['season'] = df['month'].map(season_map)

    return df

# %%
def create_advanced_features(df, is_training=True):
    """
    Create advanced features for insurance premium prediction with proper scaling
    """
    df = df.copy()

    # Store scaling factors during training
    if is_training:
        global scale_params
        scale_params = {
            'health_score_mean': df['health_score'].mean(),
            'health_score_std': df['health_score'].std(),
            'credit_score_mean': df['credit_score'].mean(),
            'credit_score_std': df['credit_score'].std(),
            'customer_feedback_map': {
                'Poor': 0.0,    # Higher risk
                'Average': 0.5, # Medium risk
                'Good': 1.0     # Lower risk
            },
            'exercise_frequency_map': {
                'Rarely': 0.0,   # Highest risk
                'Monthly': 0.33, # High risk
                'Weekly': 0.66,  # Low risk
                'Daily': 1.0     # Lowest risk
            },
            'smoking_map': {
                'Yes': 1.0,  # Higher risk
                'No': 0.0    # Lower risk
            },
            'marital_risk_map': {
                'Single': 1.0,    # Base risk
                'Married': 0.8,   # Lower risk (shared responsibility)
                'Divorced': 1.2   # Higher risk (potentially more financial stress)
            },
            'property_risk_map': {
                'Apartment': 1.0,  # Base risk
                'House': 1.5,     # Higher risk (more value/larger space)
                'Condo': 1.2      # Medium risk
            }
        }

    # 1. Date-based features
    df = create_date_features(df)

    # 2. Income-based features with proper scaling
    df['income_per_dependent'] = df['annual_income'] / (df['number_of_dependents'] + 1)
    df['income_bracket'] = pd.qcut(df['annual_income'], q=5,
                                 labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])

    # 3. Risk Score Combinations with standardization
    # Standardize health and credit scores
    df['health_score_std'] = (df['health_score'] - scale_params['health_score_mean']) / scale_params['health_score_std']
    df['credit_score_std'] = (df['credit_score'] - scale_params['credit_score_mean']) / scale_params['credit_score_std']

    # Combined risk score (now both features are on same scale)
    df['total_risk_score'] = df['health_score_std'] + df['credit_score_std']

    # Claims ratio with insurance duration
    df['claims_to_duration_ratio'] = df['previous_claims'] / (df['insurance_duration'] + 1)

    # 4. Age-related interactions
    df['vehicle_to_driver_age_ratio'] = df['vehicle_age'] / df['age']
    df['is_young_driver'] = (df['age'] < 25).astype(int)
    df['is_senior_driver'] = (df['age'] > 65).astype(int)

    # 5. Lifestyle Score (normalized to 0-1 range)
    df['exercise_score'] = df['exercise_frequency'].map(scale_params['exercise_frequency_map'])
    df['smoking_risk'] = df['smoking_status'].map(scale_params['smoking_map'])
    df['lifestyle_score'] = (
        df['exercise_score'] * 0.4 +    # Exercise has significant impact
        (1 - df['smoking_risk']) * 0.4 + # Non-smoking is positive
        (df['health_score_std'] > 0) * 0.2  # Above average health is positive
    )

    # 6. Location-based features
    if is_training:
        scale_params['location_risk_map'] = df.groupby('location')['previous_claims'].mean()
        scale_params['location_credit_map'] = df.groupby('location')['credit_score'].mean()

    df['location_risk'] = df['location'].map(scale_params['location_risk_map'])
    df['location_avg_credit'] = df['location'].map(scale_params['location_credit_map'])

    # 7. Complex Interaction Features
    df['customer_feedback_score'] = df['customer_feedback'].map(scale_params['customer_feedback_map'])

    # Weighted responsibility score (all components now 0-1 scaled)
    df['responsibility_score'] = (
        df['credit_score_std'].clip(-3, 3) * 0.4 +  # Limit outlier effect
        df['customer_feedback_score'] * 0.3 +
        (1 - df['claims_to_duration_ratio'].clip(0, 1)) * 0.3  # Lower claims is better
    )

    # 8. Family and Property Risk
    df['marital_risk'] = df['marital_status'].map(scale_params['marital_risk_map'])
    df['property_risk'] = df['property_type'].map(scale_params['property_risk_map'])

    # Combined risk factors
    df['family_risk_factor'] = df['marital_risk'] * (df['number_of_dependents'] + 1)
    df['asset_risk'] = (
        df['property_risk'] * 0.6 +
        (df['vehicle_age'] / df['vehicle_age'].max()) * 0.4  # Normalized vehicle age
    )

    # 9. Customer Segment Features
    df['premium_segment'] = 'Standard'
    mask_premium = (
        (df['credit_score_std'] > 1) &  # Above 1 std in credit
        (df['previous_claims'] == 0) &   # No claims
        (df['health_score_std'] > 1)     # Above 1 std in health
    )
    mask_high_risk = (
        (df['credit_score_std'] < -1) |  # Below 1 std in credit
        (df['previous_claims'] > 3)       # Multiple claims
    )

    df.loc[mask_premium, 'premium_segment'] = 'Premium'
    df.loc[mask_high_risk, 'premium_segment'] = 'High Risk'

    # 10. Additional Ratio Features
    df['claims_per_year'] = df['previous_claims'] / (df['insurance_duration'] + 1)
    df['dependent_income_ratio'] = df['number_of_dependents'] / df['annual_income']

    # Drop intermediate columns
    intermediate_cols = ['health_score_std', 'credit_score_std', 'exercise_score',
                        'smoking_risk', 'customer_feedback_score', 'marital_risk',
                        'property_risk']
    df = df.drop(columns=[col for col in intermediate_cols if col in df.columns])

    return df

# %%
try:
    # Transform training data
    train_transformed = create_advanced_features(train, is_training=True)
    print("Training data transformation successful!")

    # Transform test data
    test_transformed = create_advanced_features(test, is_training=False)
    print("Test data transformation successful!")

except Exception as e:
    print(f"An error occurred: {str(e)}")
    print("Please check your data types and column names.")

# %%
# Lets do one more transformation
train_transformed['premium_amount_log'] = np.log10(train_transformed['premium_amount'])

# %% [markdown]
# # **Autogluon Train**

# %%
# # Create the AutoGluon scorer using sklearn's implementation
# rmsle_scorer = make_scorer(
#     name='rmsle',
#     score_func=sklearn.metrics.root_mean_squared_log_error,
#     optimum=0,
#     greater_is_better=False,
#     needs_pred=True
# )

# %%
# Setting up
eval_metric = 'rmse'
label = 'premium_amount_log'
problem_type='regression'
hours = 4
autogluon_path = os.getenv('DATA_FOLDER_PATH', '/content/drive/MyDrive/DS_Projects/Playground_Series/Ps4e12_Regression_Insuranse_Premium_Prediction/Autogluon/')

# Initialize the TabularPredictor
predictor = TabularPredictor(label=label,
                             problem_type=problem_type,
                             eval_metric=eval_metric,
                             path = os.path.join(autogluon_path, "202412_ps4s12_4hr_training"))

# Fit the model
predictor.fit(train_data=train_transformed.drop(columns="premium_amount"),
              time_limit=3600*hours,
              presets="best_quality",
              num_stack_levels=2,
              dynamic_stacking=False
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="Autogluon/202412_ps4s12_4hr_training"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          96
# Memory Avail:       326.30 GB / 334.56 GB (97.5%)
# Disk Space Avail:   206.24 GB / 225.33 GB (91.5%)
# ===================================================
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=2, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 14400s
# AutoGluon will save models to "/content/Autogluon/202412_ps4s12_4hr_training"
# Train Data Rows:    1200000
# Train Data Columns: 59
# Label Column:       premium_amount_log
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    335051.20 MB
# 	Train Data (Original)  Memory Usage: 1465.39 MB (0.4% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 8 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['year_cos', 'is_senior_driver']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 1): ['claims_per_year']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 1 | ['claims_per_year']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', [])                   :  1 | ['income_bracket']
# 		('datetime', [])                   :  1 | ['policy_start']
# 		('float', [])                      : 24 | ['age', 'annual_income', 'number_of_dependents', 'health_score', 'previous_claims', ...]
# 		('int', [])                        : 15 | ['year', 'month', 'day', 'week_of_year', 'quarter', ...]
# 		('object', [])                     : 14 | ['gender', 'marital_status', 'education_level', 'occupation', 'location', ...]
# 		('object', ['datetime_as_object']) :  1 | ['policy_start_date']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 13 | ['marital_status', 'education_level', 'occupation', 'location', 'policy_type', ...]
# 		('float', [])                : 24 | ['age', 'annual_income', 'number_of_dependents', 'health_score', 'previous_claims', ...]
# 		('int', [])                  :  9 | ['year', 'month', 'day', 'week_of_year', 'quarter', ...]
# 		('int', ['bool'])            :  8 | ['gender', 'smoking_status', 'is_weekend', 'is_month_end', 'is_month_start', ...]
# 		('int', ['datetime_as_int']) :  2 | ['policy_start_date', 'policy_start_date.dayofweek']
# 	13.7s = Fit runtime
# 	56 features in original data used to generate 56 features in processed data.
# 	Train Data (Processed) Memory Usage: 317.01 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 15.42s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 3 stack levels (L1 to L3) ...
# Fitting 108 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 6391.55s of the 14384.57s of remaining time.
# 	-0.5242	 = Validation score   (-root_mean_squared_error)
# 	2.27s	 = Training   runtime
# 	61.58s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 6324.38s of the 14317.40s of remaining time.
# 	-0.5242	 = Validation score   (-root_mean_squared_error)
# 	2.07s	 = Training   runtime
# 	61.68s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 6258.84s of the 14251.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.62%)
# 	-0.4578	 = Validation score   (-root_mean_squared_error)
# 	78.19s	 = Training   runtime
# 	15.48s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 6169.50s of the 14162.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.62%)
# 	-0.4567	 = Validation score   (-root_mean_squared_error)
# 	22.48s	 = Training   runtime
# 	2.6s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 6143.37s of the 14136.39s of remaining time.
# 	-0.4575	 = Validation score   (-root_mean_squared_error)
# 	319.4s	 = Training   runtime
# 	62.68s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 5759.49s of the 13752.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.63%)
# 	-0.4573	 = Validation score   (-root_mean_squared_error)
# 	2942.32s	 = Training   runtime
# 	0.95s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2813.67s of the 10806.70s of remaining time.
# 	-0.4577	 = Validation score   (-root_mean_squared_error)
# 	135.47s	 = Training   runtime
# 	64.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2612.06s of the 10605.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=1.10%)
# 	-0.4585	 = Validation score   (-root_mean_squared_error)
# 	1198.74s	 = Training   runtime
# 	14.09s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1408.02s of the 9401.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.83%)
# 	Warning: Exception caused XGBoost_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=57749, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 118, in _fit
#     X = self.preprocess(X, is_train=True, max_category_levels=max_category_levels)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 426, in preprocess
#     X = self._preprocess(X, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 78, in _preprocess
#     X = self._ohe_generator.transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/xgboost/xgboost_utils.py", line 155, in transform
#     X_list.append(self.ohe_encs.transform(X[self.cat_cols]))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 2106, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(AttributeError): ray::_ray_fit() (pid=57749, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 118, in _fit
#     X = self.preprocess(X, is_train=True, max_category_levels=max_category_levels)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 426, in preprocess
#     X = self._preprocess(X, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 78, in _preprocess
#     X = self._ohe_generator.transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/xgboost/xgboost_utils.py", line 155, in transform
#     X_list.append(self.ohe_encs.transform(X[self.cat_cols]))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1399.53s of the 9392.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.60%)
# 2024-12-29 20:07:49,319	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:07:49,321	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:07:49,323	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:07:49,324	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:07:49,325	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:07:49,326	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:07:49,327	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=58829, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 744, in _process_train_data
#     df = self.processor.fit_transform(df)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 1000, in fit_transform
#     result = self._call_func_on_transformers(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 909, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 1540, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 728, in fit_transform
#     return last_step.fit_transform(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 918, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 2106, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(AttributeError): ray::_ray_fit() (pid=58829, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 744, in _process_train_data
#     df = self.processor.fit_transform(df)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 1000, in fit_transform
#     result = self._call_func_on_transformers(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 909, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 1540, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 728, in fit_transform
#     return last_step.fit_transform(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 918, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1381.88s of the 9374.90s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.64%)
# 2024-12-29 20:08:07,327	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:08:07,329	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:08:07,331	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:08:07,332	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:08:07,333	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:08:07,334	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:08:07,334	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.4568	 = Validation score   (-root_mean_squared_error)
# 	23.51s	 = Training   runtime
# 	2.71s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1354.57s of the 9347.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.63%)
# 	-0.4574	 = Validation score   (-root_mean_squared_error)
# 	392.55s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 958.53s of the 8951.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.60%)
# 	Warning: Exception caused NeuralNetTorch_r79_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=67168, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 744, in _process_train_data
#     df = self.processor.fit_transform(df)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 1000, in fit_transform
#     result = self._call_func_on_transformers(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 909, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 1540, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 728, in fit_transform
#     return last_step.fit_transform(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 918, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 2106, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(AttributeError): ray::_ray_fit() (pid=67168, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 744, in _process_train_data
#     df = self.processor.fit_transform(df)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 1000, in fit_transform
#     result = self._call_func_on_transformers(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 909, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 1540, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 728, in fit_transform
#     return last_step.fit_transform(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 918, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 940.87s of the 8933.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.63%)
# 2024-12-29 20:15:28,674	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:15:28,676	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:15:28,677	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:15:28,678	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:15:28,679	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:15:28,680	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 20:15:28,681	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.4568	 = Validation score   (-root_mean_squared_error)
# 	108.93s	 = Training   runtime
# 	21.97s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 825.91s of the 8818.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=1.10%)
# 	-0.4621	 = Validation score   (-root_mean_squared_error)
# 	607.0s	 = Training   runtime
# 	26.86s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 212.38s of the 8205.40s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.65%)
# 	-0.4571	 = Validation score   (-root_mean_squared_error)
# 	168.59s	 = Training   runtime
# 	1.59s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 40.16s of the 8033.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.63%)
# 	-0.4599	 = Validation score   (-root_mean_squared_error)
# 	31.92s	 = Training   runtime
# 	12.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 3.20s of the 7996.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.60%)
# 	Warning: Exception caused NeuralNetTorch_r22_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=868001, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 744, in _process_train_data
#     df = self.processor.fit_transform(df)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 1000, in fit_transform
#     result = self._call_func_on_transformers(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 909, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
# ...
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.74%)
# 	-0.4562	 = Validation score   (-root_mean_squared_error)
# 	40.72s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L3 ... Training model for up to 101.72s of the 101.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.71%)
# 	Warning: Exception caused NeuralNetTorch_r79_BAG_L3 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=2652619, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 744, in _process_train_data
#     df = self.processor.fit_transform(df)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 1000, in fit_transform
#     result = self._call_func_on_transformers(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 909, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 1540, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 728, in fit_transform
#     return last_step.fit_transform(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 918, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 2106, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/trainer/abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(AttributeError): ray::_ray_fit() (pid=2652619, ip=172.28.0.12)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/core/models/abstract/abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 744, in _process_train_data
#     df = self.processor.fit_transform(df)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 1000, in fit_transform
#     result = self._call_func_on_transformers(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py", line 909, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 1540, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py", line 728, in fit_transform
#     return last_step.fit_transform(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 918, in fit_transform
#     return self.fit(X, **fit_params).transform(X)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/autogluon/tabular/models/tabular_nn/utils/categorical_encoders.py", line 483, in transform
#     check_is_fitted(self, "categories_")
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py", line 1751, in check_is_fitted
#     tags = get_tags(estimator)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py", line 405, in get_tags
#     sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 859, in __sklearn_tags__
#     tags = super().__sklearn_tags__()
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# Fitting model: LightGBM_r131_BAG_L3 ... Training model for up to 77.45s of the 77.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.74%)
# 2024-12-29 22:43:05,073	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:43:05,075	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:43:05,076	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:43:05,077	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:43:05,079	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:43:05,080	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:43:05,081	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.4562	 = Validation score   (-root_mean_squared_error)
# 	40.44s	 = Training   runtime
# 	3.78s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L3 ... Training model for up to 32.18s of the 31.90s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=1.29%)
# 	Time limit exceeded... Skipping NeuralNetFastAI_r191_BAG_L3.
# Fitting model: CatBoost_r9_BAG_L3 ... Training model for up to 16.68s of the 16.40s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=12, gpus=0, memory=0.77%)
# 2024-12-29 22:44:06,116	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:44:06,117	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:44:06,118	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:44:06,121	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:44:06,122	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:44:06,123	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2024-12-29 22:44:06,124	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.4659	 = Validation score   (-root_mean_squared_error)
# 	10.97s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 360.00s of the 0.47s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 0.286, 'LightGBM_BAG_L3': 0.143, 'LightGBMLarge_BAG_L3': 0.143, 'RandomForestMSE_BAG_L2': 0.071, 'LightGBMLarge_BAG_L2': 0.071, 'CatBoost_r9_BAG_L2': 0.071, 'CatBoost_BAG_L3': 0.071, 'NeuralNetFastAI_BAG_L3': 0.071, 'LightGBM_r131_BAG_L3': 0.071}
# 	-0.4562	 = Validation score   (-root_mean_squared_error)
# 	5.21s	 = Training   runtime
# 	0.02s	 = Validation runtime
# AutoGluon training complete, total runtime = 14405.67s ... Best model: WeightedEnsemble_L4 | Estimated inference throughput: 614.5 rows/s (150000 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/Autogluon/202412_ps4s12_4hr_training")

# %% [markdown]
# # **Best Submission**

# %%
predictor = TabularPredictor.load(os.path.join(autogluon_path, "202412_ps4s12_4hr_training"))

# %%
leaderboard_test = predictor.leaderboard(silent=True)
leaderboard_test
# Out:
#                           model  score_val              eval_metric  \
# 0           WeightedEnsemble_L4  -0.456175  root_mean_squared_error
# 1           WeightedEnsemble_L3  -0.456184  root_mean_squared_error
# 2          LightGBM_r131_BAG_L3  -0.456222  root_mean_squared_error
# 3               CatBoost_BAG_L3  -0.456222  root_mean_squared_error
# 4               LightGBM_BAG_L3  -0.456225  root_mean_squared_error
# 5          CatBoost_r177_BAG_L3  -0.456227  root_mean_squared_error
# 6               CatBoost_BAG_L2  -0.456238  root_mean_squared_error
# 7          LightGBM_r131_BAG_L2  -0.456242  root_mean_squared_error
# 8            CatBoost_r9_BAG_L2  -0.456242  root_mean_squared_error
# 9        NeuralNetFastAI_BAG_L3  -0.456245  root_mean_squared_error
# 10            LightGBMXT_BAG_L3  -0.456256  root_mean_squared_error
# 11              LightGBM_BAG_L2  -0.456268  root_mean_squared_error
# 12         CatBoost_r177_BAG_L2  -0.456275  root_mean_squared_error
# 13         LightGBMLarge_BAG_L3  -0.456288  root_mean_squared_error
# 14         LightGBMLarge_BAG_L2  -0.456309  root_mean_squared_error
# 15            LightGBMXT_BAG_L2  -0.456326  root_mean_squared_error
# 16          LightGBM_r96_BAG_L2  -0.456346  root_mean_squared_error
# 17          WeightedEnsemble_L2  -0.456477  root_mean_squared_error
# 18       NeuralNetFastAI_BAG_L2  -0.456483  root_mean_squared_error
# 19  NeuralNetFastAI_r191_BAG_L2  -0.456705  root_mean_squared_error
# 20              LightGBM_BAG_L1  -0.456723  root_mean_squared_error
# 21         LightGBMLarge_BAG_L1  -0.456757  root_mean_squared_error
# 22         LightGBM_r131_BAG_L1  -0.456784  root_mean_squared_error
# 23         ExtraTreesMSE_BAG_L2  -0.456800  root_mean_squared_error
# 24         ExtraTreesMSE_BAG_L3  -0.456821  root_mean_squared_error
# 25           CatBoost_r9_BAG_L1  -0.457111  root_mean_squared_error
# 26       RandomForestMSE_BAG_L2  -0.457151  root_mean_squared_error
# 27       RandomForestMSE_BAG_L3  -0.457305  root_mean_squared_error
# 28              CatBoost_BAG_L1  -0.457319  root_mean_squared_error
# 29         CatBoost_r177_BAG_L1  -0.457359  root_mean_squared_error
# 30       RandomForestMSE_BAG_L1  -0.457525  root_mean_squared_error
# 31         ExtraTreesMSE_BAG_L1  -0.457711  root_mean_squared_error
# 32            LightGBMXT_BAG_L1  -0.457825  root_mean_squared_error
# 33       NeuralNetFastAI_BAG_L1  -0.458471  root_mean_squared_error
# 34          LightGBM_r96_BAG_L1  -0.459918  root_mean_squared_error
# 35  NeuralNetFastAI_r191_BAG_L1  -0.462130  root_mean_squared_error
# 36           CatBoost_r9_BAG_L3  -0.465889  root_mean_squared_error
# 37        KNeighborsUnif_BAG_L1  -0.524189  root_mean_squared_error
# 38        KNeighborsDist_BAG_L1  -0.524189  root_mean_squared_error
#
#     pred_time_val      fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0      592.019967  12168.401034                0.018989           5.205663
# 1      436.102431   8028.720071                0.016997           1.734774
# 2      573.205613  11032.514372                3.781716          40.444908
# 3      570.072577  11290.144512                0.648680         298.075048
# 4      570.893403  11005.059917                1.469506          12.990453
# 5      569.875735  11032.793932                0.451839          40.724468
# 6      350.131260   6992.651333                0.706634         959.211804
# 7      354.036047   6090.532742                4.611421          57.093213
# 8      350.168216   6204.375225                0.743590         170.935696
# 9      584.303429  11790.138528               14.879533         798.069064
# 10     570.824951  11006.872334                1.401055          14.802870
# 11     351.026806   6050.017307                1.602180          16.577778
# 12     349.894121   6162.422603                0.469495         128.983074
# 13     571.221543  11013.615899                1.797647          21.546435
# 14     351.463673   6057.684477                2.039047          24.244948
# 15     351.225696   6052.283477                1.801070          18.843948
# 16     368.962706   6164.040142               19.538080         130.600613
# 17      91.418267   3811.348406                0.017445           2.158762
# 18     364.045986   7200.804737               14.621360        1167.365208
# 19     375.923330   7348.742767               26.498704        1315.303238
# 20       2.598159     22.484616                2.598159          22.484616
# 21       2.705384     23.508922                2.705384          23.508922
# 22      21.974341    108.927403               21.974341         108.927403
# 23     418.232201   6220.849838               68.807575         187.410309
# 24     633.475255  11169.911235               64.051359         177.841771
# 25       1.592718    168.589138                1.592718         168.589138
# 26     427.984742   6815.499635               78.560116         782.060106
# 27     649.929918  11860.755573               80.506022         868.686109
# 28       0.952226   2942.318911                0.952226        2942.318911
# 29       0.490490    392.549623                0.490490         392.549623
# 30      62.680223    319.400169               62.680223         319.400169
# 31      64.278058    135.468114               64.278058         135.468114
# 32      15.477087     78.193379               15.477087          78.193379
# 33      14.087080   1198.742366               14.087080        1198.742366
# 34      12.469407     31.924768               12.469407          31.924768
# 35      26.860490    606.999320               26.860490         606.999320
# 36     569.872374  11003.038061                0.448478          10.968597
# 37      61.580464      2.267260               61.580464           2.267260
# 38      61.678501      2.065540               61.678501           2.065540
#
#     stack_level  can_infer  fit_order
# 0             4       True         39
# 1             3       True         28
# 2             3       True         37
# 3             3       True         32
# 4             3       True         30
# 5             3       True         36
# 6             2       True         19
# 7             2       True         24
# 8             2       True         26
# 9             3       True         34
# 10            3       True         29
# 11            2       True         17
# 12            2       True         23
# 13            3       True         35
# 14            2       True         22
# 15            2       True         16
# 16            2       True         27
# 17            2       True         15
# 18            2       True         21
# 19            2       True         25
# 20            1       True          4
# 21            1       True          9
# 22            1       True         11
# 23            2       True         20
# 24            3       True         33
# 25            1       True         13
# 26            2       True         18
# 27            3       True         31
# 28            1       True          6
# 29            1       True         10
# 30            1       True          5
# 31            1       True          7
# 32            1       True          3
# 33            1       True          8
# 34            1       True         14
# 35            1       True         12
# 36            3       True         38
# 37            1       True          1
# 38            1       True          2

# %%
models = leaderboard_test.head(5)['model'].to_list()
best_model = models[0]
print("Best model by autogluon is", models[0])
print("With a score of RMSLE", np.abs(leaderboard_test[leaderboard_test['model']==best_model]['score_val'][0]))

training = "4hr_log_tpu"
sub_autogluon = submission.copy()
sub_autogluon['premium_amount_log'] = predictor.predict(test_transformed, as_pandas=False, model=best_model)
sub_autogluon['Premium Amount'] = np.power(10, sub_autogluon['premium_amount_log'])
sub_autogluon.drop(columns="premium_amount_log", inplace=True)
sub_autogluon.to_csv(os.path.join(base_path, f'submission_{best_model}_{training}.csv'), index=False)
# Out:
# Best model by autogluon is WeightedEnsemble_L4
# With a score of RMSLE 0.45617460214772926

# %% [markdown]
# # **Saving OOFs**

# %%
def save_experiment_oofs(predictor, models, experiment_name, path, islog=True):
    """
    Save OOF predictions as a single DataFrame with experiment identifier in column names
    """
    # Create DataFrame with index from training data
    oof_df = pd.DataFrame(index=predictor.predict_oof().index)

    # Add OOF predictions for each model with experiment identifier
    for i, model in enumerate(models, 1):
        print(f"Generating OOF predictions for {model} - {i}/{len(models)}")
        oof_preds = predictor.predict_oof(model=model)
        if islog:
            oof_preds = np.power(10, oof_preds)
        col_name = f"{experiment_name}_{model}"
        oof_df[col_name] = oof_preds

    # Save DataFrame
    filename = f"oof_preds_{experiment_name}.parquet"
    filepath = os.path.join(path, filename)

    oof_df.to_parquet(filepath)
    print(f"Saved {len(models)} model predictions for experiment {experiment_name}")
    return oof_df

# Saving OOFs for later use
oofs_path = os.getenv('DATA_FOLDER_PATH', '/content/drive/MyDrive/DS_Projects/Playground_Series/Ps4e12_Regression_Insuranse_Premium_Prediction/Data/oofs/')
models = leaderboard_test['model'].to_list()
experiment_name = "4log"
oof_df = save_experiment_oofs(predictor, models, experiment_name, oofs_path)
# Out:
# Generating OOF predictions for WeightedEnsemble_L4 - 0/39
# Generating OOF predictions for WeightedEnsemble_L3 - 1/39
# Generating OOF predictions for LightGBM_r131_BAG_L3 - 2/39
# Generating OOF predictions for CatBoost_BAG_L3 - 3/39
# Generating OOF predictions for LightGBM_BAG_L3 - 4/39
# Generating OOF predictions for CatBoost_r177_BAG_L3 - 5/39
# Generating OOF predictions for CatBoost_BAG_L2 - 6/39
# Generating OOF predictions for LightGBM_r131_BAG_L2 - 7/39
# Generating OOF predictions for CatBoost_r9_BAG_L2 - 8/39
# Generating OOF predictions for NeuralNetFastAI_BAG_L3 - 9/39
# Generating OOF predictions for LightGBMXT_BAG_L3 - 10/39
# Generating OOF predictions for LightGBM_BAG_L2 - 11/39
# Generating OOF predictions for CatBoost_r177_BAG_L2 - 12/39
# Generating OOF predictions for LightGBMLarge_BAG_L3 - 13/39
# Generating OOF predictions for LightGBMLarge_BAG_L2 - 14/39
# Generating OOF predictions for LightGBMXT_BAG_L2 - 15/39
# Generating OOF predictions for LightGBM_r96_BAG_L2 - 16/39
# Generating OOF predictions for WeightedEnsemble_L2 - 17/39
# Generating OOF predictions for NeuralNetFastAI_BAG_L2 - 18/39
# Generating OOF predictions for NeuralNetFastAI_r191_BAG_L2 - 19/39
# Generating OOF predictions for LightGBM_BAG_L1 - 20/39
# Generating OOF predictions for LightGBMLarge_BAG_L1 - 21/39
# Generating OOF predictions for LightGBM_r131_BAG_L1 - 22/39
# Generating OOF predictions for ExtraTreesMSE_BAG_L2 - 23/39
# Generating OOF predictions for ExtraTreesMSE_BAG_L3 - 24/39
# Generating OOF predictions for CatBoost_r9_BAG_L1 - 25/39
# Generating OOF predictions for RandomForestMSE_BAG_L2 - 26/39
# Generating OOF predictions for RandomForestMSE_BAG_L3 - 27/39
# Generating OOF predictions for CatBoost_BAG_L1 - 28/39
# Generating OOF predictions for CatBoost_r177_BAG_L1 - 29/39
# Generating OOF predictions for RandomForestMSE_BAG_L1 - 30/39
# Generating OOF predictions for ExtraTreesMSE_BAG_L1 - 31/39
# Generating OOF predictions for LightGBMXT_BAG_L1 - 32/39
# Generating OOF predictions for NeuralNetFastAI_BAG_L1 - 33/39
# Generating OOF predictions for LightGBM_r96_BAG_L1 - 34/39
# Generating OOF predictions for NeuralNetFastAI_r191_BAG_L1 - 35/39
# Generating OOF predictions for CatBoost_r9_BAG_L3 - 36/39
# Generating OOF predictions for KNeighborsUnif_BAG_L1 - 37/39
# Generating OOF predictions for KNeighborsDist_BAG_L1 - 38/39
# Saved 39 model predictions for experiment 4nonlog
